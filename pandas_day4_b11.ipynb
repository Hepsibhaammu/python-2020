# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\prave\\Downloads\\artwork_data.csv',index_col='id',usecols=['id','artist'])
print(df)
# Out:
#                     artist
# id
# 1035         Blake, Robert
# 1036         Blake, Robert
# 1037         Blake, Robert
# 1038         Blake, Robert
# 1039        Blake, William
# ...                    ...
# 122960  P-Orridge, Genesis
# 122961  P-Orridge, Genesis
# 121181        Hatoum, Mona
# 112306       Creed, Martin
# 127035   Brunias, Agostino
#
# [69201 rows x 1 columns]

# %%
df.to_pickle('C:\Hepsibha\python class 2020\dataframe1.pickle')#pickle is a defult serialization format

# %%
df2=pd.read_pickle("C:\Hepsibha\python class 2020\dataframe1.pickle")

print(df2)
# Out:
#                     artist
# id
# 1035         Blake, Robert
# 1036         Blake, Robert
# 1037         Blake, Robert
# 1038         Blake, Robert
# 1039        Blake, William
# ...                    ...
# 122960  P-Orridge, Genesis
# 122961  P-Orridge, Genesis
# 121181        Hatoum, Mona
# 112306       Creed, Martin
# 127035   Brunias, Agostino
#
# [69201 rows x 1 columns]

# %%
introducing to indexing and filttering in pandas:
    1.how many distinct artist are there in the data set?
    2.how many atworks by blake,william are there?
    3.what is the art work with the biggest dimensions?
# Out:
#   File "<ipython-input-16-90e73c58654d>", line 1
#     introducing to indexing and filttering in pandas:
#                  ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv('C:\\Users\\prave\\Downloads\\artwork_data.csv')
df
# Out:
# C:\Users\prave\Anaconda3n\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (9,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# ...

# %%
artist=df['artist']

# %%
pd.unique(artist)
# Out:
# array(['Blake, Robert', 'Blake, William', 'Richmond, George', ...,
#        'Sterne, Hedda', 'P-Orridge, Genesis', 'Brunias, Agostino'],
#       dtype=object)

# %%
len(pd.unique(artist))
# Out:
# 3336

# %%
s=df['artist']=='Bacon,Francis'
s.value_counts()
# Out:
# False    69201
# Name: artist, dtype: int64

# %%
s=df['artist']=='blake,william'
s.value_counts()
# Out:
# False    69201
# Name: artist, dtype: int64

# %%
introduction to loc and iloc

loc----->lable(work with direct col names)
iloc----->position (working with indexing)

# %%
#df.loc[rowindex,colindex]
df.loc[1035,'artist']
df
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
df.iloc[100:300,[9,1,4]]
df
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
Area=height*width

# %%
df['height']*df['width']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3n\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# ~\Anaconda3n\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3n\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     126     if result is None:
# --> 127         result = _evaluate_standard(op, op_str, a, b)
#     128
#
# ...

# %%
#height and width cols

# %%
df['height'].sort_values().head()
df['height'].sort_values().tail()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3n\lib\site-packages\pandas\core\series.py in _try_kind_sort(arr)
#    3149                 # if kind==mergesort, it can fail for object dtype
# -> 3150                 return arr.argsort(kind=kind)
#    3151             except TypeError:
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-b4a3a661f39e> in <module>
# ----> 1 df['height'].sort_values().head()
#       2 df['height'].sort_values().tail()
#
# ~\Anaconda3n\lib\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    3162         idx = ibase.default_index(len(self))
#    3163
# ...

# %%
df['width'].sort_values().head()
# Out:
# 62198           (1):
# 68540    (diameter):
# 2427         (each):
# 54196        (each):
# 67796       (image):
# Name: width, dtype: object

# %%
df['width'].sort_values().tail()
# Out:
# 69188    NaN
# 69190    NaN
# 69191    NaN
# 69193    NaN
# 69199    NaN
# Name: width, dtype: object

# %%
pd.to_numeric(df['width'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "(upper):"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-281c1c37b21d> in <module>
# ----> 1 pd.to_numeric(df['width'])
#
# ~\Anaconda3n\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     149             coerce_numeric = errors not in ("ignore", "raise")
#     150             values = lib.maybe_convert_numeric(
# --> 151                 values, set(), coerce_numeric=coerce_numeric
#     152             )
#     153
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "(upper):" at position 1839

# %%
a=pd.to_numeric(df['width'],errors='coerce')
print(a)
# Out:
# 0        394.0
# 1        311.0
# 2        343.0
# 3        318.0
# 4        243.0
#          ...
# 69196    305.0
# 69197    305.0
# 69198     45.0
# 69199      NaN
# 69200    508.0
# Name: width, Length: 69201, dtype: float64

# %%
a*b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-8ce765dcfa30> in <module>
# ----> 1 a*b
#
# NameError: name 'b' is not defined

# %%
b=pd.to_numeric(df['height'],errors='coerce')
print(b)
# Out:
# 0         419.0
# 1         213.0
# 2         467.0
# 3         394.0
# 4         335.0
#           ...
# 69196     305.0
# 69197     305.0
# 69198    2410.0
# 69199       NaN
# 69200     660.0
# Name: height, Length: 69201, dtype: float64

# %%
a*b
# Out:
# 0        165086.0
# 1         66243.0
# 2        160181.0
# 3        125292.0
# 4         81405.0
#            ...
# 69196     93025.0
# 69197     93025.0
# 69198    108450.0
# 69199         NaN
# 69200    335280.0
# Length: 69201, dtype: float64

# %%
area=a*b
print(area)
# Out:
# 0        165086.0
# 1         66243.0
# 2        160181.0
# 3        125292.0
# 4         81405.0
#            ...
# 69196     93025.0
# 69197     93025.0
# 69198    108450.0
# 69199         NaN
# 69200    335280.0
# Length: 69201, dtype: float64

# %%
area.max()
# Out:
# 132462000.0
