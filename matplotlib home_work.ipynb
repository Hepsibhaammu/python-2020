# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('C:\\Users\prave\Downloads\countries.csv')

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
#req:to compare the population of united states and china.

# %%
gr=data[data.country=='Germany']
fr=data[data.country=='France']
eg=data[data.country=='Egypt']
dm=data[data.country=='Denmark']

# %%
gr
# Out:
#      country  year  population
# 564  Germany  1952    69145952
# 565  Germany  1957    71019069
# 566  Germany  1962    73739117
# 567  Germany  1967    76368453
# 568  Germany  1972    78717088
# 569  Germany  1977    78160773
# 570  Germany  1982    78335266
# 571  Germany  1987    77718298
# 572  Germany  1992    80597764
# 573  Germany  1997    82011073
# 574  Germany  2002    82350671
# 575  Germany  2007    82400996

# %%
fr
# Out:
#     country  year  population
# 528  France  1952    42459667
# 529  France  1957    44310863
# 530  France  1962    47124000
# 531  France  1967    49569000
# 532  France  1972    51732000
# 533  France  1977    53165019
# 534  France  1982    54433565
# 535  France  1987    55630100
# 536  France  1992    57374179
# 537  France  1997    58623428
# 538  France  2002    59925035
# 539  France  2007    61083916

# %%
eg
# Out:
#     country  year  population
# 456   Egypt  1952    22223309
# 457   Egypt  1957    25009741
# 458   Egypt  1962    28173309
# 459   Egypt  1967    31681188
# 460   Egypt  1972    34807417
# 461   Egypt  1977    38783863
# 462   Egypt  1982    45681811
# 463   Egypt  1987    52799062
# 464   Egypt  1992    59402198
# 465   Egypt  1997    66134291
# 466   Egypt  2002    73312559
# 467   Egypt  2007    80264543

# %%
dm
# Out:
#      country  year  population
# 408  Denmark  1952     4334000
# 409  Denmark  1957     4487831
# 410  Denmark  1962     4646899
# 411  Denmark  1967     4838800
# 412  Denmark  1972     4991596
# 413  Denmark  1977     5088419
# 414  Denmark  1982     5117810
# 415  Denmark  1987     5127024
# 416  Denmark  1992     5171393
# 417  Denmark  1997     5283663
# 418  Denmark  2002     5374693
# 419  Denmark  2007     5468120

# %%
india=data[data.country=='India']

# %%
india
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
plt.plot(india.year,india.population)
plt.show()

# %%
plt.plot(india.year,india.population/10**6)
plt.show()

# %%
plt.plot(india.year,india.population/10**6)
plt.plot(gr.year,gr.population/10**6)
plt.plot(fr.year,fr.population/10**6)
plt.plot(eg.year,eg.population/10**6)
plt.plot(dm.year,dm.population/10**6)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(gr.year,gr.population/10)
plt.plot(india.year,india.population/10)
plt.plot(dm.year,dm.population/10)
plt.plot(fr.year,fr.population/10)
plt.plot(eg.year,eg.population/10)
plt.legend(['india','germany','denmark','france','egypt'])
plt.xlabel('year')
plt.ylabel('population')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
